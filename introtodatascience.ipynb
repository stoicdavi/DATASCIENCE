# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt #creating static, animated, and interactive visualizations
x = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y1 = [1, 3, 5, 3, 1, 3, 5, 3, 1]
y2 = [2, 4, 6, 4, 2, 4, 6, 4, 2]
plt.plot(x, y1, label="SEM1")
plt.plot(x, y2, label="SEM2")
plt.plot()
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("DISTRIBUTION PER SEMESTER")
plt.legend() #used to des

# %%
import matplotlib.pyplot as plt
x1 = ["BSE","BBIT", "BSCIT", "BCS", "BCM"]
y1 = [200, 400, 250, 180, 180]
plt.bar(x1, y1, label="yellow Bar", color='y')
plt.plot()
plt.xlabel("COURSE")
plt.ylabel("NUMBER OF STUDENTS")
plt.title("INTAKE AS PER THE COURSES")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
labels = 'A', 'B', 'C', 'D'
sections = [56, 66, 24, 60]
colors = ['c','g','r','y']
explode = (0.1, 0.1, 0.2, 0)
plt.pie(sections, labels=labels, colors=colors, startangle=90, explode=explode)
plt.title("GRADES FOR DATA SCIENCE")
plt.show()

# %%
myinfo = pd.read_csv('studentPerformance.csv')
print(myinfo.head())
# Out:
#               Name  English  Database  Calculus  Computer Support  \
# 0  Abraham Lincoln       97        78        75                73
# 1     John Kennedy       87        87        89                76
# 2    David Beckham       89        83        70                77
# 3     Jeremy David       83        81        85                87
# 4      Enock Ariel       85        97        89                99
#
#    Artificial Intelligence  Total  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0                       87    410         NaN         NaN         NaN  ...
# 1                       83    422         NaN         NaN         NaN  ...
# 2                       82    401         NaN         NaN         NaN  ...
# 3                       89    425         NaN         NaN         NaN  ...
# 4                       76    446         NaN         NaN         NaN  ...
#
#    Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 26 columns]
